# %%
import pandas as pd
import feedparser
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from datetime import datetime
import requests
import time

# RSS Feeds from trusted financial and news sources
feeds = {
    'Reuters': 'http://feeds.reuters.com/reuters/businessNews',
    'Bloomberg': 'https://www.bloomberg.com/feed/podcast/etfreport.xml',
    'Economic Times': 'https://economictimes.indiatimes.com/rssfeedsdefault.cms',
    'Financial Times': 'https://www.ft.com/?format=rss',
    'Wall Street Journal': 'https://feeds.a.dj.com/rss/RSSMarketsMain.xml',
    'BBC News': 'http://feeds.bbci.co.uk/news/business/rss.xml'
}

# Fetch articles from RSS feeds
def fetch_rss_feed(feed_url):
    feed = feedparser.parse(feed_url)
    articles = []
    for entry in feed.entries:
        # Handle the summary field safely, default to an empty string if not present
        summary = entry.get('summary', '')

        # Handle the published date safely
        published = None
        if 'published_parsed' in entry:
            published = datetime(*entry.published_parsed[:6])

        article = {
            'title': entry.title,
            'link': entry.link,
            'published': published,
            'summary': summary
        }
        articles.append(article)
    return articles

# Fetch articles from GDELT (for historical news)
def fetch_gdelt_articles(company, start_date, end_date):
    url = f"https://api.gdeltproject.org/api/v2/doc/doc?query={company}&mode=artlist&startdatetime={start_date}&enddatetime={end_date}&format=json"
    
    try:
        response = requests.get(url)
        
        # Check if the response is valid
        if response.status_code == 200 and response.content:
            try:
                json_data = response.json()
                if json_data and 'articles' in json_data:
                    return json_data['articles']
                else:
                    print(f"No articles found for {company} in GDELT.")
                    return []
            except ValueError:
                print(f"Error parsing GDELT data for {company}: Invalid JSON")
                return []
        else:
            print(f"GDELT API returned non-200 status or empty response for {company}. Status Code: {response.status_code}")
            return []
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching GDELT data for {company}: {e}")
        return []

# Keywords to identify fresh events
fresh_event_keywords = ["today", "just now", "announced", "introduced", "launched", "reported", "unveiled", "breaking news"]

# Filter fresh events
def filter_fresh_events(articles):
    fresh_events = []
    for article in articles:
        title_lower = article['title'].lower()
        summary_lower = article['summary'].lower()
        if any(keyword in title_lower or keyword in summary_lower for keyword in fresh_event_keywords):
            fresh_events.append(article)
    return fresh_events

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Perform sentiment analysis
def calculate_sentiment(article):
    sentiment = analyzer.polarity_scores(article['summary'])
    article['sentiment_score'] = sentiment['compound']  # Store compound score
    return article

def analyze_sentiment_for_articles(articles):
    for article in articles:
        article = calculate_sentiment(article)
    return articles

# Aggregate sentiment scores by date
def aggregate_sentiment_by_day(articles, company_name):
    df = pd.DataFrame(articles)
    if not df.empty and 'published' in df.columns:
        df['date'] = df['published'].dt.date  # Extract the date from published datetime
        daily_sentiment = df.groupby('date')['sentiment_score'].mean().reset_index()
        daily_sentiment['company'] = company_name
        return daily_sentiment
    return pd.DataFrame()  # Return empty DataFrame if no valid data

# Process each company to fetch news, calculate sentiment, and aggregate scores
def process_company(ticker, company_name):
    print(f"Processing company: {company_name} (Ticker: {ticker})...")  # Print the company name and ticker

    # Define start and end dates
    start_date = "19900101"
    end_date = "20240930"

    # Fetch articles from all RSS feeds
    rss_articles = []
    for source, feed_url in feeds.items():
        rss_articles.extend(fetch_rss_feed(feed_url))
    
    # Fetch historical articles from GDELT
    gdelt_articles = fetch_gdelt_articles(company_name, start_date, end_date)

    # Combine RSS and GDELT articles
    all_articles = rss_articles + gdelt_articles

    # Filter fresh events
    fresh_events = filter_fresh_events(all_articles)

    # Perform sentiment analysis
    fresh_events_with_sentiment = analyze_sentiment_for_articles(fresh_events)

    # Aggregate sentiment scores by date
    aggregated_sentiment = aggregate_sentiment_by_day(fresh_events_with_sentiment, company_name)

    return aggregated_sentiment

# Load your ticker file (NSE_tickers.csv) and namechange file (namechange.csv)
ticker_file = 'NSE_tickers.csv'
namechange_file = 'namechange.csv'

# Load the ticker file
tickers_df = pd.read_csv(ticker_file)

# Try loading with ISO-8859-1 encoding
namechange_df = pd.read_csv(namechange_file, encoding='ISO-8859-1')

# Merge the tickers with the company names using 'SYMBOL' as the key
tickers_df = tickers_df.merge(namechange_df[['SYMBOL', 'COMPANY']], left_on='SYMBOL', right_on='SYMBOL', how='left')

# Drop any rows where we couldn't find the company name
tickers_df = tickers_df.dropna(subset=['COMPANY'])

# Process companies in batches
all_sentiment_data = []
company_counter = 0  # Counter to track the number of companies processed

for index, row in tickers_df.iterrows():
    # Print the company being processed
    print(f"Starting processing for company: {row['COMPANY']} (Ticker: {row['SYMBOL']})")
    
    sentiment_data = process_company(row['SYMBOL'], row['COMPANY'])
    
    if not sentiment_data.empty:
        all_sentiment_data.append(sentiment_data)
        company_counter += 1  # Increment the company counter
    
    # Save intermediate results after processing 2 companies
    if company_counter == 2:
        # Combine sentiment data for the first two companies
        intermediate_df = pd.concat(all_sentiment_data)
        
        # Save intermediate results
        intermediate_df.to_csv('intermediate_sentiment_dataset.csv', index=False)
        print("Intermediate results saved to 'intermediate_sentiment_dataset.csv'")
        # Optionally, break here to verify the data before continuing
        # break
    
    # Add delay between requests to avoid rate limiting
    time.sleep(1)  # Adjust the delay if necessary

# Continue processing the rest of the companies and save final results
if all_sentiment_data:
    final_df = pd.concat(all_sentiment_data)

    # Save the final dataset
    final_df.to_csv('company_sentiment_dataset.csv', index=False)
    print("Final data saved to 'company_sentiment_dataset.csv'")
else:
    print("No sentiment data found for the companies processed.")
# Out:
# Starting processing for company: 360 ONE WAM LIMITED (Ticker: 360ONE)
# Processing company: 360 ONE WAM LIMITED (Ticker: 360ONE)...
# Error parsing GDELT data for 360 ONE WAM LIMITED: Invalid JSON
# Starting processing for company: 3M India Limited (Ticker: 3MINDIA)
# Processing company: 3M India Limited (Ticker: 3MINDIA)...
# Error parsing GDELT data for 3M India Limited: Invalid JSON
# Intermediate results saved to 'intermediate_sentiment_dataset.csv'
# Starting processing for company: 3P Land Holdings Limited (Ticker: 3PLAND)
# Processing company: 3P Land Holdings Limited (Ticker: 3PLAND)...
# Error parsing GDELT data for 3P Land Holdings Limited: Invalid JSON
# Starting processing for company: 63 moons technologies limited (Ticker: 63MOONS)
# Processing company: 63 moons technologies limited (Ticker: 63MOONS)...
# Error parsing GDELT data for 63 moons technologies limited: Invalid JSON
# Starting processing for company: A2Z INFRA ENGINEERING LIMITED (Ticker: A2ZINFRA)
# Processing company: A2Z INFRA ENGINEERING LIMITED (Ticker: A2ZINFRA)...
# Error parsing GDELT data for A2Z INFRA ENGINEERING LIMITED: Invalid JSON
# Starting processing for company: Aban Offshore Limited (Ticker: ABAN)
# Processing company: Aban Offshore Limited (Ticker: ABAN)...
# Error parsing GDELT data for Aban Offshore Limited: Invalid JSON
# Starting processing for company: ABB India Limited (Ticker: ABB)
# Processing company: ABB India Limited (Ticker: ABB)...
# Error parsing GDELT data for ABB India Limited: Invalid JSON
# Starting processing for company: Aditya Birla Fashion and Retail Limited (Ticker: ABFRL)
# Processing company: Aditya Birla Fashion and Retail Limited (Ticker: ABFRL)...
# Error parsing GDELT data for Aditya Birla Fashion and Retail Limited: Invalid JSON
# Starting processing for company: ACC Limited (Ticker: ACC)
# Processing company: ACC Limited (Ticker: ACC)...
# Error parsing GDELT data for ACC Limited: Invalid JSON
# Starting processing for company: Accelya Solutions India Limited (Ticker: ACCELYA)
# Processing company: Accelya Solutions India Limited (Ticker: ACCELYA)...
# Error parsing GDELT data for Accelya Solutions India Limited: Invalid JSON
# Starting processing for company: GATI Limited (Ticker: ACLGATI)
# Processing company: GATI Limited (Ticker: ACLGATI)...
# Error parsing GDELT data for GATI Limited: Invalid JSON
# Starting processing for company: Allcargo Gati Limited (Ticker: ACLGATI)
# Processing company: Allcargo Gati Limited (Ticker: ACLGATI)...
# Error parsing GDELT data for Allcargo Gati Limited: Invalid JSON
# Starting processing for company: Adani Energy Solutions Limited (Ticker: ADANIENSOL)
# Processing company: Adani Energy Solutions Limited (Ticker: ADANIENSOL)...
# Error parsing GDELT data for Adani Energy Solutions Limited: Invalid JSON
# Starting processing for company: Adani Enterprises Limited (Ticker: ADANIENT)
# Processing company: Adani Enterprises Limited (Ticker: ADANIENT)...
# Error parsing GDELT data for Adani Enterprises Limited: Invalid JSON
# Starting processing for company: Adani Ports and Special Economic Zone Limited (Ticker: ADANIPORTS)
# Processing company: Adani Ports and Special Economic Zone Limited (Ticker: ADANIPORTS)...
# Error parsing GDELT data for Adani Ports and Special Economic Zone Limited: Invalid JSON
# Starting processing for company: Ador Welding Limited (Ticker: ADORWELD)
# Processing company: Ador Welding Limited (Ticker: ADORWELD)...
# Error parsing GDELT data for Ador Welding Limited: Invalid JSON
# Starting processing for company: Adroit Infotech Limited (Ticker: ADROITINFO)
# Processing company: Adroit Infotech Limited (Ticker: ADROITINFO)...
# Error parsing GDELT data for Adroit Infotech Limited: Invalid JSON
# Starting processing for company: ADVANI HOTELS & RESORTS (INDIA) LIMITED (Ticker: ADVANIHOTR)
# Processing company: ADVANI HOTELS & RESORTS (INDIA) LIMITED (Ticker: ADVANIHOTR)...
# Error parsing GDELT data for ADVANI HOTELS & RESORTS (INDIA) LIMITED: Invalid JSON
# Starting processing for company: AGI Greenpac Limited (Ticker: AGI)
# Processing company: AGI Greenpac Limited (Ticker: AGI)...
# Error parsing GDELT data for AGI Greenpac Limited: Invalid JSON
# Starting processing for company: HSIL Limited (Ticker: AGI)
# Processing company: HSIL Limited (Ticker: AGI)...
# Error parsing GDELT data for HSIL Limited: Invalid JSON
# Starting processing for company: Ajmera Realty & Infra India Limited (Ticker: AJMERA)
# Processing company: Ajmera Realty & Infra India Limited (Ticker: AJMERA)...
# Error parsing GDELT data for Ajmera Realty & Infra India Limited: Invalid JSON
# Starting processing for company: Akzo Nobel India Limited (Ticker: AKZOINDIA)
# Processing company: Akzo Nobel India Limited (Ticker: AKZOINDIA)...
# Error parsing GDELT data for Akzo Nobel India Limited: Invalid JSON
# Starting processing for company: ALEMBIC LIMITED (Ticker: ALEMBICLTD)
# Processing company: ALEMBIC LIMITED (Ticker: ALEMBICLTD)...
# Error parsing GDELT data for ALEMBIC LIMITED: Invalid JSON
# Starting processing for company: ALEMBIC LTD. (Ticker: ALEMBICLTD)
# Processing company: ALEMBIC LTD. (Ticker: ALEMBICLTD)...
# Error parsing GDELT data for ALEMBIC LTD.: Invalid JSON
# Starting processing for company: Alicon Castalloy Limited (Ticker: ALICON)
# Processing company: Alicon Castalloy Limited (Ticker: ALICON)...
# Error parsing GDELT data for Alicon Castalloy Limited: Invalid JSON
# Starting processing for company: Allcargo Logistics Limited (Ticker: ALLCARGO)
# Processing company: Allcargo Logistics Limited (Ticker: ALLCARGO)...
# Error parsing GDELT data for Allcargo Logistics Limited: Invalid JSON
# Starting processing for company: Ambuja Cements Limited (Ticker: AMBUJACEM)
# Processing company: Ambuja Cements Limited (Ticker: AMBUJACEM)...
# Error parsing GDELT data for Ambuja Cements Limited: Invalid JSON
# Starting processing for company: AMD Industries Limited (Ticker: AMDIND)
# Processing company: AMD Industries Limited (Ticker: AMDIND)...
# Error parsing GDELT data for AMD Industries Limited: Invalid JSON
# Starting processing for company: Amj Land Holdings Limited (Ticker: AMJLAND)
# Processing company: Amj Land Holdings Limited (Ticker: AMJLAND)...
# Error parsing GDELT data for Amj Land Holdings Limited: Invalid JSON
# Starting processing for company: AMJ Land Holdings Limited (Ticker: AMJLAND)
# Processing company: AMJ Land Holdings Limited (Ticker: AMJLAND)...
# Error parsing GDELT data for AMJ Land Holdings Limited: Invalid JSON
# Starting processing for company: Anant Raj Limited (Ticker: ANANTRAJ)
# Processing company: Anant Raj Limited (Ticker: ANANTRAJ)...
# Error parsing GDELT data for Anant Raj Limited: Invalid JSON
# Starting processing for company: ANDHRA PAPER LIMITED (Ticker: ANDHRAPAP)
# Processing company: ANDHRA PAPER LIMITED (Ticker: ANDHRAPAP)...
# Error parsing GDELT data for ANDHRA PAPER LIMITED: Invalid JSON
# Starting processing for company: Angel One Limited (Ticker: ANGELONE)
# Processing company: Angel One Limited (Ticker: ANGELONE)...
# Error parsing GDELT data for Angel One Limited: Invalid JSON
# Starting processing for company: Anik Industries Limited (Ticker: ANIKINDS)
# Processing company: Anik Industries Limited (Ticker: ANIKINDS)...
# Error parsing GDELT data for Anik Industries Limited: Invalid JSON
# Starting processing for company: Ansal Properties & Infrastructure Limited (Ticker: ANSALAPI)
# Processing company: Ansal Properties & Infrastructure Limited (Ticker: ANSALAPI)...
# Error parsing GDELT data for Ansal Properties & Infrastructure Limited: Invalid JSON
# Starting processing for company: Antarctica Limited (Ticker: ANTGRAPHIC)
# Processing company: Antarctica Limited (Ticker: ANTGRAPHIC)...
# Error parsing GDELT data for Antarctica Limited: Invalid JSON
# Starting processing for company: Apcotex Industries Limited (Ticker: APCOTEXIND)
# Processing company: Apcotex Industries Limited (Ticker: APCOTEXIND)...
# Error parsing GDELT data for Apcotex Industries Limited: Invalid JSON
# Starting processing for company: Aptech Limited (Ticker: APTECHT)
# Processing company: Aptech Limited (Ticker: APTECHT)...
# Error parsing GDELT data for Aptech Limited: Invalid JSON
# Starting processing for company: Archies Limited (Ticker: ARCHIES)
# Processing company: Archies Limited (Ticker: ARCHIES)...
# Error parsing GDELT data for Archies Limited: Invalid JSON
# Starting processing for company: Amara Raja Energy & Mobility Limited (Ticker: ARE&M)
# Processing company: Amara Raja Energy & Mobility Limited (Ticker: ARE&M)...
# Error parsing GDELT data for Amara Raja Energy & Mobility Limited: Invalid JSON
# Starting processing for company: Rajdarshan Industries Limited (Ticker: ARENTERP)
# Processing company: Rajdarshan Industries Limited (Ticker: ARENTERP)...
# Error parsing GDELT data for Rajdarshan Industries Limited: Invalid JSON
# Starting processing for company: Arrow Greentech Limited (Ticker: ARROWGREEN)
# Processing company: Arrow Greentech Limited (Ticker: ARROWGREEN)...
# Error parsing GDELT data for Arrow Greentech Limited: Invalid JSON
# Starting processing for company: Arvind Limited (Ticker: ARVIND)
# Processing company: Arvind Limited (Ticker: ARVIND)...
# Error parsing GDELT data for Arvind Limited: Invalid JSON
# Starting processing for company: Arvind SmartSpaces Limited (Ticker: ARVSMART)
# Processing company: Arvind SmartSpaces Limited (Ticker: ARVSMART)...
# Error parsing GDELT data for Arvind SmartSpaces Limited: Invalid JSON
# Starting processing for company: Asahi India Glass Limited (Ticker: ASAHIINDIA)
# Processing company: Asahi India Glass Limited (Ticker: ASAHIINDIA)...
# Error parsing GDELT data for Asahi India Glass Limited: Invalid JSON
# Starting processing for company: Automotive Stampings and Assemblies Limited (Ticker: ASAL)
# Processing company: Automotive Stampings and Assemblies Limited (Ticker: ASAL)...
# Error parsing GDELT data for Automotive Stampings and Assemblies Limited: Invalid JSON
# Starting processing for company: Ashima Limited (Ticker: ASHIMASYN)
# Processing company: Ashima Limited (Ticker: ASHIMASYN)...
# Error parsing GDELT data for Ashima Limited: Invalid JSON
# Starting processing for company: Asian Hotels (North) Limited (Ticker: ASIANHOTNR)
# Processing company: Asian Hotels (North) Limited (Ticker: ASIANHOTNR)...
# Error parsing GDELT data for Asian Hotels (North) Limited: Invalid JSON
# Starting processing for company: Asian Paints Limited (Ticker: ASIANPAINT)
# Processing company: Asian Paints Limited (Ticker: ASIANPAINT)...
# Error parsing GDELT data for Asian Paints Limited: Invalid JSON
# Starting processing for company: Astral Limited (Ticker: ASTRAL)
# Processing company: Astral Limited (Ticker: ASTRAL)...
# Error parsing GDELT data for Astral Limited: Invalid JSON
# Starting processing for company: AstraZeneca Pharma India Limited (Ticker: ASTRAZEN)
# Processing company: AstraZeneca Pharma India Limited (Ticker: ASTRAZEN)...
# Error parsing GDELT data for AstraZeneca Pharma India Limited: Invalid JSON
# Starting processing for company: AGRO TECH FOODS LIMITED (Ticker: ATFL)
# Processing company: AGRO TECH FOODS LIMITED (Ticker: ATFL)...
# Error parsing GDELT data for AGRO TECH FOODS LIMITED: Invalid JSON
# Starting processing for company: Adani Total Gas Limited (Ticker: ATGL)
# Processing company: Adani Total Gas Limited (Ticker: ATGL)...
# Error parsing GDELT data for Adani Total Gas Limited: Invalid JSON
# Starting processing for company: ATLANTAA LIMITED (Ticker: ATLANTAA)
# Processing company: ATLANTAA LIMITED (Ticker: ATLANTAA)...
# Error parsing GDELT data for ATLANTAA LIMITED: Invalid JSON
# Starting processing for company: Atul Limited (Ticker: ATUL)
# Processing company: Atul Limited (Ticker: ATUL)...
# Error parsing GDELT data for Atul Limited: Invalid JSON
# Starting processing for company: AURUM PROPTECH LIMITED (Ticker: AURUM)
# Processing company: AURUM PROPTECH LIMITED (Ticker: AURUM)...
# Error parsing GDELT data for AURUM PROPTECH LIMITED: Invalid JSON
# Starting processing for company: Ausom Enterprise Limited (Ticker: AUSOMENT)
# Processing company: Ausom Enterprise Limited (Ticker: AUSOMENT)...
# Error parsing GDELT data for Ausom Enterprise Limited: Invalid JSON
# Starting processing for company: Automotive Axles Limited (Ticker: AUTOAXLES)
# Processing company: Automotive Axles Limited (Ticker: AUTOAXLES)...
# Error parsing GDELT data for Automotive Axles Limited: Invalid JSON
# Starting processing for company: AVRO INDIA LIMITED (Ticker: AVROIND)
# Processing company: AVRO INDIA LIMITED (Ticker: AVROIND)...
# Error parsing GDELT data for AVRO INDIA LIMITED: Invalid JSON
# Starting processing for company: Axis Bank Limited (Ticker: AXISBANK)
# Processing company: Axis Bank Limited (Ticker: AXISBANK)...
# Error parsing GDELT data for Axis Bank Limited: Invalid JSON
# Starting processing for company: AXISCADES Technologies Limited (Ticker: AXISCADES)
# Processing company: AXISCADES Technologies Limited (Ticker: AXISCADES)...
# Error parsing GDELT data for AXISCADES Technologies Limited: Invalid JSON
# Starting processing for company: AYM Syntex Limited (Ticker: AYMSYNTEX)
# Processing company: AYM Syntex Limited (Ticker: AYMSYNTEX)...
# Error parsing GDELT data for AYM Syntex Limited: Invalid JSON
# Starting processing for company: B.A.G Films and Media Limited (Ticker: BAGFILMS)
# Processing company: B.A.G Films and Media Limited (Ticker: BAGFILMS)...
# Error parsing GDELT data for B.A.G Films and Media Limited: Invalid JSON
# Starting processing for company: Bajaj Consumer Care Limited (Ticker: BAJAJCON)
# Processing company: Bajaj Consumer Care Limited (Ticker: BAJAJCON)...
# Error parsing GDELT data for Bajaj Consumer Care Limited: Invalid JSON
# Starting processing for company: Bajaj Hindusthan Sugar Limited (Ticker: BAJAJHIND)
# Processing company: Bajaj Hindusthan Sugar Limited (Ticker: BAJAJHIND)...
# Error parsing GDELT data for Bajaj Hindusthan Sugar Limited: Invalid JSON
# Starting processing for company: Bajaj Holdings & Investment Limited (Ticker: BAJAJHLDNG)
# Processing company: Bajaj Holdings & Investment Limited (Ticker: BAJAJHLDNG)...
# Error parsing GDELT data for Bajaj Holdings & Investment Limited: Invalid JSON
# Starting processing for company: Bajaj Finance Limited (Ticker: BAJFINANCE)
# Processing company: Bajaj Finance Limited (Ticker: BAJFINANCE)...
# Error parsing GDELT data for Bajaj Finance Limited: Invalid JSON
# Starting processing for company: BALAXI PHARMACEUTICALS LIMITED (Ticker: BALAXI)
# Processing company: BALAXI PHARMACEUTICALS LIMITED (Ticker: BALAXI)...
# Error parsing GDELT data for BALAXI PHARMACEUTICALS LIMITED: Invalid JSON
# Starting processing for company: Balkrishna Paper Mills Limited (Ticker: BALKRISHNA)
# Processing company: Balkrishna Paper Mills Limited (Ticker: BALKRISHNA)...
# Error parsing GDELT data for Balkrishna Paper Mills Limited: Invalid JSON
# Starting processing for company: Black Box Limited (Ticker: BBOX)
# Processing company: Black Box Limited (Ticker: BBOX)...
# Error parsing GDELT data for Black Box Limited: Invalid JSON
# Starting processing for company: AGC Networks Limited (Ticker: BBOX)
# Processing company: AGC Networks Limited (Ticker: BBOX)...
# Error parsing GDELT data for AGC Networks Limited: Invalid JSON
# Starting processing for company: BEML Limited (Ticker: BEML)
# Processing company: BEML Limited (Ticker: BEML)...
# Error parsing GDELT data for BEML Limited: Invalid JSON
# Starting processing for company: Bharti Airtel Limited (Ticker: BHARTIARTL)
# Processing company: Bharti Airtel Limited (Ticker: BHARTIARTL)...
# Error parsing GDELT data for Bharti Airtel Limited: Invalid JSON
# Starting processing for company: Birla Cable Limited (Ticker: BIRLACABLE)
# Processing company: Birla Cable Limited (Ticker: BIRLACABLE)...
# Error parsing GDELT data for Birla Cable Limited: Invalid JSON
# Starting processing for company: Birla Corporation Limited (Ticker: BIRLACORPN)
# Processing company: Birla Corporation Limited (Ticker: BIRLACORPN)...
# Error parsing GDELT data for Birla Corporation Limited: Invalid JSON
# Starting processing for company: Aditya Birla Money Limited (Ticker: BIRLAMONEY)
# Processing company: Aditya Birla Money Limited (Ticker: BIRLAMONEY)...
# Error parsing GDELT data for Aditya Birla Money Limited: Invalid JSON
# Starting processing for company: BOROSIL RENEWABLES LIMITED (Ticker: BORORENEW)
# Processing company: BOROSIL RENEWABLES LIMITED (Ticker: BORORENEW)...
# Error parsing GDELT data for BOROSIL RENEWABLES LIMITED: Invalid JSON
# Starting processing for company: Bosch Limited (Ticker: BOSCHLTD)
# Processing company: Bosch Limited (Ticker: BOSCHLTD)...
# Error parsing GDELT data for Bosch Limited: Invalid JSON
# Starting processing for company: BIRLASOFT LIMITED (Ticker: BSOFT)
# Processing company: BIRLASOFT LIMITED (Ticker: BSOFT)...
# Error parsing GDELT data for BIRLASOFT LIMITED: Invalid JSON
# Starting processing for company: Career Point Limited (Ticker: CAREERP)
# Processing company: Career Point Limited (Ticker: CAREERP)...
# Error parsing GDELT data for Career Point Limited: Invalid JSON
# Starting processing for company: CARE Ratings Limited (Ticker: CARERATING)
# Processing company: CARE Ratings Limited (Ticker: CARERATING)...
# Error parsing GDELT data for CARE Ratings Limited: Invalid JSON
# Starting processing for company: CARYSIL LIMITED (Ticker: CARYSIL)
# Processing company: CARYSIL LIMITED (Ticker: CARYSIL)...
# Error parsing GDELT data for CARYSIL LIMITED: Invalid JSON
# Starting processing for company: Centum Electronics Limited (Ticker: CENTUM)
# Processing company: Centum Electronics Limited (Ticker: CENTUM)...
# Error parsing GDELT data for Centum Electronics Limited: Invalid JSON
# Starting processing for company: Capri Global Capital Limited (Ticker: CGCL)
# Processing company: Capri Global Capital Limited (Ticker: CGCL)...
# Error parsing GDELT data for Capri Global Capital Limited: Invalid JSON
# Starting processing for company: CG Power and Industrial Solutions Limited (Ticker: CGPOWER)
# Processing company: CG Power and Industrial Solutions Limited (Ticker: CGPOWER)...
# Error parsing GDELT data for CG Power and Industrial Solutions Limited: Invalid JSON
# Starting processing for company: Chennai Petroleum Corporation Limited (Ticker: CHENNPETRO)
# Processing company: Chennai Petroleum Corporation Limited (Ticker: CHENNPETRO)...
# Error parsing GDELT data for Chennai Petroleum Corporation Limited: Invalid JSON
# Starting processing for company: Chennai Petroleum Corporation Limited (Ticker: CHENNPETRO)
# Processing company: Chennai Petroleum Corporation Limited (Ticker: CHENNPETRO)...
# Error parsing GDELT data for Chennai Petroleum Corporation Limited: Invalid JSON
# Starting processing for company: Cholamandalam Investment and Finance Company Limited (Ticker: CHOLAFIN)
# Processing company: Cholamandalam Investment and Finance Company Limited (Ticker: CHOLAFIN)...
# Error parsing GDELT data for Cholamandalam Investment and Finance Company Limited: Invalid JSON
# Starting processing for company: Cholamandalam Financial Holdings Limited (Ticker: CHOLAHLDNG)
# Processing company: Cholamandalam Financial Holdings Limited (Ticker: CHOLAHLDNG)...
# Error parsing GDELT data for Cholamandalam Financial Holdings Limited: Invalid JSON
# Starting processing for company: Mahindra CIE Automotive Limited (Ticker: CIEINDIA)
# Processing company: Mahindra CIE Automotive Limited (Ticker: CIEINDIA)...
# Error parsing GDELT data for Mahindra CIE Automotive Limited: Invalid JSON
# Starting processing for company: CIE Automotive India Limited (Ticker: CIEINDIA)
# Processing company: CIE Automotive India Limited (Ticker: CIEINDIA)...
# Error parsing GDELT data for CIE Automotive India Limited: Invalid JSON
# Starting processing for company: Cineline India Limited (Ticker: CINELINE)
# Processing company: Cineline India Limited (Ticker: CINELINE)...
# Error parsing GDELT data for Cineline India Limited: Invalid JSON
# Starting processing for company: Cinevista Limited (Ticker: CINEVISTA)
# Processing company: Cinevista Limited (Ticker: CINEVISTA)...
# Error parsing GDELT data for Cinevista Limited: Invalid JSON
# Starting processing for company: Coforge Limited (Ticker: COFORGE)
# Processing company: Coforge Limited (Ticker: COFORGE)...
# Error parsing GDELT data for Coforge Limited: Invalid JSON
# Starting processing for company: Coromandel International Limited (Ticker: COROMANDEL)
# Processing company: Coromandel International Limited (Ticker: COROMANDEL)...
# Error parsing GDELT data for Coromandel International Limited: Invalid JSON
# Starting processing for company: COSMO FIRST LIMITED (Ticker: COSMOFIRST)
# Processing company: COSMO FIRST LIMITED (Ticker: COSMOFIRST)...
# Error parsing GDELT data for COSMO FIRST LIMITED: Invalid JSON
# Starting processing for company: Country Condo's Limited (Ticker: COUNCODOS)
# Processing company: Country Condo's Limited (Ticker: COUNCODOS)...
# Error parsing GDELT data for Country Condo's Limited: Invalid JSON
# Starting processing for company: Creative Newtech Limited (Ticker: CREATIVE)
# Processing company: Creative Newtech Limited (Ticker: CREATIVE)...
# Error parsing GDELT data for Creative Newtech Limited: Invalid JSON
# Starting processing for company: Crest Ventures Limited (Ticker: CREST)
# Processing company: Crest Ventures Limited (Ticker: CREST)...
# Error parsing GDELT data for Crest Ventures Limited: Invalid JSON
# Starting processing for company: CRISIL Limited (Ticker: CRISIL)
# Processing company: CRISIL Limited (Ticker: CRISIL)...
# Error parsing GDELT data for CRISIL Limited: Invalid JSON
# Starting processing for company: Cummins India Limited (Ticker: CUMMINSIND)
# Processing company: Cummins India Limited (Ticker: CUMMINSIND)...
# Error parsing GDELT data for Cummins India Limited: Invalid JSON
# Starting processing for company: Cyient Limited (Ticker: CYIENT)
# Processing company: Cyient Limited (Ticker: CYIENT)...
# Error parsing GDELT data for Cyient Limited: Invalid JSON
# Starting processing for company: Dalmia Bharat Limited (Ticker: DALBHARAT)
# Processing company: Dalmia Bharat Limited (Ticker: DALBHARAT)...
# Error parsing GDELT data for Dalmia Bharat Limited: Invalid JSON
# Starting processing for company: Dalmia Bharat Sugar and Industries Limited (Ticker: DALMIASUG)
# Processing company: Dalmia Bharat Sugar and Industries Limited (Ticker: DALMIASUG)...
# Error parsing GDELT data for Dalmia Bharat Sugar and Industries Limited: Invalid JSON
# Starting processing for company: Datamatics Global Services Limited (Ticker: DATAMATICS)
# Processing company: Datamatics Global Services Limited (Ticker: DATAMATICS)...
# Error parsing GDELT data for Datamatics Global Services Limited: Invalid JSON
# Starting processing for company: Valor Estate Limited (Ticker: DBREALTY)
# Processing company: Valor Estate Limited (Ticker: DBREALTY)...
# Error parsing GDELT data for Valor Estate Limited: Invalid JSON
# Starting processing for company: DCB BANK LIMITED (Ticker: DCBBANK)
# Processing company: DCB BANK LIMITED (Ticker: DCBBANK)...
# Error parsing GDELT data for DCB BANK LIMITED: Invalid JSON
# Starting processing for company: DCM Shriram Limited (Ticker: DCMSHRIRAM)
# Processing company: DCM Shriram Limited (Ticker: DCMSHRIRAM)...
# Error parsing GDELT data for DCM Shriram Limited: Invalid JSON
# Starting processing for company: DEEP ENERGY RESOURCES LIMITED (Ticker: DEEPENR)
# Processing company: DEEP ENERGY RESOURCES LIMITED (Ticker: DEEPENR)...
# Error parsing GDELT data for DEEP ENERGY RESOURCES LIMITED: Invalid JSON
# Starting processing for company: DELPHI WORLD MONEY LIMITED (Ticker: DELPHIFX)
# Processing company: DELPHI WORLD MONEY LIMITED (Ticker: DELPHIFX)...
# Error parsing GDELT data for DELPHI WORLD MONEY LIMITED: Invalid JSON
# Starting processing for company: EBIXCASH WORLD MONEY INDIA LIMITED (Ticker: DELPHIFX)
# Processing company: EBIXCASH WORLD MONEY INDIA LIMITED (Ticker: DELPHIFX)...
# Error parsing GDELT data for EBIXCASH WORLD MONEY INDIA LIMITED: Invalid JSON
# Starting processing for company: Delta Corp Limited (Ticker: DELTACORP)
# Processing company: Delta Corp Limited (Ticker: DELTACORP)...
# Error parsing GDELT data for Delta Corp Limited: Invalid JSON
# Starting processing for company: Delta Manufacturing Limited (Ticker: DELTAMAGNT)
# Processing company: Delta Manufacturing Limited (Ticker: DELTAMAGNT)...
# Error parsing GDELT data for Delta Manufacturing Limited: Invalid JSON
# Starting processing for company: De Nora India Limited (Ticker: DENORA)
# Processing company: De Nora India Limited (Ticker: DENORA)...
# Error parsing GDELT data for De Nora India Limited: Invalid JSON
# Starting processing for company: Dhampur Sugar Mills Limited (Ticker: DHAMPURSUG)
# Processing company: Dhampur Sugar Mills Limited (Ticker: DHAMPURSUG)...
# Error parsing GDELT data for Dhampur Sugar Mills Limited: Invalid JSON
# Starting processing for company: Dhanlaxmi Bank Limited (Ticker: DHANBANK)
# Processing company: Dhanlaxmi Bank Limited (Ticker: DHANBANK)...
# Error parsing GDELT data for Dhanlaxmi Bank Limited: Invalid JSON
# Starting processing for company: Dhani Services Limited (Ticker: DHANI)
# Processing company: Dhani Services Limited (Ticker: DHANI)...
# Error parsing GDELT data for Dhani Services Limited: Invalid JSON
# Starting processing for company: DIC India Limited (Ticker: DICIND)
# Processing company: DIC India Limited (Ticker: DICIND)...
# Error parsing GDELT data for DIC India Limited: Invalid JSON
# Starting processing for company: DiGiSPICE Technologies Limited (Ticker: DIGISPICE)
# Processing company: DiGiSPICE Technologies Limited (Ticker: DIGISPICE)...
# Error parsing GDELT data for DiGiSPICE Technologies Limited: Invalid JSON
# Starting processing for company: Debock Industries Limited (Ticker: DIL)
# Processing company: Debock Industries Limited (Ticker: DIL)...
# Error parsing GDELT data for Debock Industries Limited: Invalid JSON
# Starting processing for company: DMCC SPECIALITY CHEMICALS LIMITED (Ticker: DMCC)
# Processing company: DMCC SPECIALITY CHEMICALS LIMITED (Ticker: DMCC)...
# Error parsing GDELT data for DMCC SPECIALITY CHEMICALS LIMITED: Invalid JSON
# Starting processing for company: Dolat Algotech Limited (Ticker: DOLATALGO)
# Processing company: Dolat Algotech Limited (Ticker: DOLATALGO)...
# Error parsing GDELT data for Dolat Algotech Limited: Invalid JSON
# Starting processing for company: Ducon Infratechnologies Limited (Ticker: DUCON)
# Processing company: Ducon Infratechnologies Limited (Ticker: DUCON)...
# Error parsing GDELT data for Ducon Infratechnologies Limited: Invalid JSON
# Starting processing for company: Dhunseri Ventures Limited (Ticker: DVL)
# Processing company: Dhunseri Ventures Limited (Ticker: DVL)...
# Error parsing GDELT data for Dhunseri Ventures Limited: Invalid JSON
# Starting processing for company: Edelweiss Financial Services Limited (Ticker: EDELWEISS)
# Processing company: Edelweiss Financial Services Limited (Ticker: EDELWEISS)...
# Error parsing GDELT data for Edelweiss Financial Services Limited: Invalid JSON
# Starting processing for company: EIH ASSOCIATED HOTELS LIMITED (Ticker: EIHAHOTELS)
# Processing company: EIH ASSOCIATED HOTELS LIMITED (Ticker: EIHAHOTELS)...
# Error parsing GDELT data for EIH ASSOCIATED HOTELS LIMITED: Invalid JSON
# Starting processing for company: EIH LIMITED (Ticker: EIHOTEL)
# Processing company: EIH LIMITED (Ticker: EIHOTEL)...
# Error parsing GDELT data for EIH LIMITED: Invalid JSON
# Starting processing for company: Emami Realty Limited (Ticker: EMAMIREAL)
# Processing company: Emami Realty Limited (Ticker: EMAMIREAL)...
# Error parsing GDELT data for Emami Realty Limited: Invalid JSON
# Starting processing for company: Equinox India Developments Limited (Ticker: EMBDL)
# Processing company: Equinox India Developments Limited (Ticker: EMBDL)...
# Error parsing GDELT data for Equinox India Developments Limited: Invalid JSON
# Starting processing for company: Emkay Global Financial Services Limited (Ticker: EMKAY)
# Processing company: Emkay Global Financial Services Limited (Ticker: EMKAY)...
# Error parsing GDELT data for Emkay Global Financial Services Limited: Invalid JSON
# Starting processing for company: Emmbi Industries Limited (Ticker: EMMBI)
# Processing company: Emmbi Industries Limited (Ticker: EMMBI)...
# Error parsing GDELT data for Emmbi Industries Limited: Invalid JSON
# Starting processing for company: Epigral Limited (Ticker: EPIGRAL)
# Processing company: Epigral Limited (Ticker: EPIGRAL)...
# Error parsing GDELT data for Epigral Limited: Invalid JSON
# Starting processing for company: EPL Limited (Ticker: EPL)
# Processing company: EPL Limited (Ticker: EPL)...
# Error parsing GDELT data for EPL Limited: Invalid JSON
# Starting processing for company: Equippp Social Impact Technologies Limited (Ticker: EQUIPPP)
# Processing company: Equippp Social Impact Technologies Limited (Ticker: EQUIPPP)...
# Error parsing GDELT data for Equippp Social Impact Technologies Limited: Invalid JSON
# Starting processing for company: Escorts Kubota Limited (Ticker: ESCORTS)
# Processing company: Escorts Kubota Limited (Ticker: ESCORTS)...
# Error parsing GDELT data for Escorts Kubota Limited: Invalid JSON
# Starting processing for company: Integra Essentia Limited (Ticker: ESSENTIA)
# Processing company: Integra Essentia Limited (Ticker: ESSENTIA)...
# Error parsing GDELT data for Integra Essentia Limited: Invalid JSON
# Starting processing for company: Everest Industries Limited (Ticker: EVERESTIND)
# Processing company: Everest Industries Limited (Ticker: EVERESTIND)...
# Error parsing GDELT data for Everest Industries Limited: Invalid JSON
# Starting processing for company: Excel Realty N Infra Limited (Ticker: EXCEL)
# Processing company: Excel Realty N Infra Limited (Ticker: EXCEL)...
# Error parsing GDELT data for Excel Realty N Infra Limited: Invalid JSON
# Starting processing for company: Exide Industries Limited (Ticker: EXIDEIND)
# Processing company: Exide Industries Limited (Ticker: EXIDEIND)...
# Error parsing GDELT data for Exide Industries Limited: Invalid JSON
# Starting processing for company: Expleo Solutions Limited (Ticker: EXPLEOSOL)
# Processing company: Expleo Solutions Limited (Ticker: EXPLEOSOL)...
# Error parsing GDELT data for Expleo Solutions Limited: Invalid JSON
# Starting processing for company: FUTURE ENTERPRISES LIMITED (Ticker: FEL)
# Processing company: FUTURE ENTERPRISES LIMITED (Ticker: FEL)...
# Error parsing GDELT data for FUTURE ENTERPRISES LIMITED: Invalid JSON
# Starting processing for company: Future Enterprises Limited (Ticker: FELDVR)
# Processing company: Future Enterprises Limited (Ticker: FELDVR)...
# Error parsing GDELT data for Future Enterprises Limited: Invalid JSON
# Starting processing for company: Flexituff Ventures International Limited (Ticker: FLEXITUFF)
# Processing company: Flexituff Ventures International Limited (Ticker: FLEXITUFF)...
# Error parsing GDELT data for Flexituff Ventures International Limited: Invalid JSON
# Starting processing for company: Federal-Mogul Goetze (India) Limited. (Ticker: FMGOETZE)
# Processing company: Federal-Mogul Goetze (India) Limited. (Ticker: FMGOETZE)...
# Error parsing GDELT data for Federal-Mogul Goetze (India) Limited.: Invalid JSON
# Starting processing for company: Future Market Networks Limited (Ticker: FMNL)
# Processing company: Future Market Networks Limited (Ticker: FMNL)...
# Error parsing GDELT data for Future Market Networks Limited: Invalid JSON
# Starting processing for company: FORCE MOTORS LTD (Ticker: FORCEMOT)
# Processing company: FORCE MOTORS LTD (Ticker: FORCEMOT)...
# Error parsing GDELT data for FORCE MOTORS LTD: Invalid JSON
# Starting processing for company: Fortis Healthcare Limited (Ticker: FORTIS)
# Processing company: Fortis Healthcare Limited (Ticker: FORTIS)...
# Error parsing GDELT data for Fortis Healthcare Limited: Invalid JSON
# Starting processing for company: Fusion Finance Limited (Ticker: FUSION)
# Processing company: Fusion Finance Limited (Ticker: FUSION)...
# Error parsing GDELT data for Fusion Finance Limited: Invalid JSON
# Starting processing for company: GAIL (India) Limited (Ticker: GAIL)
# Processing company: GAIL (India) Limited (Ticker: GAIL)...
# Error parsing GDELT data for GAIL (India) Limited: Invalid JSON
# Starting processing for company: Gallantt Ispat Limited (Ticker: GALLANTT)
# Processing company: Gallantt Ispat Limited (Ticker: GALLANTT)...
# Error parsing GDELT data for Gallantt Ispat Limited: Invalid JSON
# Starting processing for company: Ganesh Housing Corporation Limited (Ticker: GANESHHOUC)
# Processing company: Ganesh Housing Corporation Limited (Ticker: GANESHHOUC)...
# Error parsing GDELT data for Ganesh Housing Corporation Limited: Invalid JSON
# Starting processing for company: Garware Technical Fibres Limited (Ticker: GARFIBRES)
# Processing company: Garware Technical Fibres Limited (Ticker: GARFIBRES)...
# Error parsing GDELT data for Garware Technical Fibres Limited: Invalid JSON
# Starting processing for company: GACM Technologies Limited (Ticker: GATECH)
# Processing company: GACM Technologies Limited (Ticker: GATECH)...
# Error parsing GDELT data for GACM Technologies Limited: Invalid JSON
# Starting processing for company: GACM Technologies Limited (Ticker: GATECHDVR)
# Processing company: GACM Technologies Limited (Ticker: GATECHDVR)...
# Error parsing GDELT data for GACM Technologies Limited: Invalid JSON
# Starting processing for company: GeeCee Ventures Limited (Ticker: GEECEE)
# Processing company: GeeCee Ventures Limited (Ticker: GEECEE)...
# Error parsing GDELT data for GeeCee Ventures Limited: Invalid JSON
# Starting processing for company: Genus Power Infrastructures Limited (Ticker: GENUSPOWER)
# Processing company: Genus Power Infrastructures Limited (Ticker: GENUSPOWER)...
# Error parsing GDELT data for Genus Power Infrastructures Limited: Invalid JSON
# Starting processing for company: Geojit Financial Services Limited (Ticker: GEOJITFSL)
# Processing company: Geojit Financial Services Limited (Ticker: GEOJITFSL)...
# Error parsing GDELT data for Geojit Financial Services Limited: Invalid JSON
# Starting processing for company: GE Power India Limited (Ticker: GEPIL)
# Processing company: GE Power India Limited (Ticker: GEPIL)...
# Error parsing GDELT data for GE Power India Limited: Invalid JSON
# Starting processing for company: GE T&D India Limited (Ticker: GET&D)
# Processing company: GE T&D India Limited (Ticker: GET&D)...
# Error parsing GDELT data for GE T&D India Limited: Invalid JSON
# Starting processing for company: GFL Limited (Ticker: GFLLIMITED)
# Processing company: GFL Limited (Ticker: GFLLIMITED)...
# Error parsing GDELT data for GFL Limited: Invalid JSON
# Starting processing for company: GHCL Limited (Ticker: GHCL)
# Processing company: GHCL Limited (Ticker: GHCL)...
# Error parsing GDELT data for GHCL Limited: Invalid JSON
# Starting processing for company: GILLETTE INDIA LIMITED (Ticker: GILLETTE)
# Processing company: GILLETTE INDIA LIMITED (Ticker: GILLETTE)...
# Error parsing GDELT data for GILLETTE INDIA LIMITED: Invalid JSON
# Starting processing for company: GlaxoSmithKline Pharmaceuticals Limited (Ticker: GLAXO)
# Processing company: GlaxoSmithKline Pharmaceuticals Limited (Ticker: GLAXO)...
# Error parsing GDELT data for GlaxoSmithKline Pharmaceuticals Limited: Invalid JSON
# Starting processing for company: GMR Airports Infrastructure Limited (Ticker: GMRINFRA)
# Processing company: GMR Airports Infrastructure Limited (Ticker: GMRINFRA)...
# Error parsing GDELT data for GMR Airports Infrastructure Limited: Invalid JSON
# Starting processing for company: Gujarat Narmada Valley Fertilizers and Chemicals Limited (Ticker: GNFC)
# Processing company: Gujarat Narmada Valley Fertilizers and Chemicals Limited (Ticker: GNFC)...
# Error parsing GDELT data for Gujarat Narmada Valley Fertilizers and Chemicals Limited: Invalid JSON
# Starting processing for company: GOCL CORPORATION LIMITED (Ticker: GOCLCORP)
# Processing company: GOCL CORPORATION LIMITED (Ticker: GOCLCORP)...
# Error parsing GDELT data for GOCL CORPORATION LIMITED: Invalid JSON
# Starting processing for company: Golden Tobacco Limited (Ticker: GOLDENTOBC)
# Processing company: Golden Tobacco Limited (Ticker: GOLDENTOBC)...
# Error parsing GDELT data for Golden Tobacco Limited: Invalid JSON
# Starting processing for company: AION-TECH SOLUTIONS LIMITED (Ticker: GOLDTECH)
# Processing company: AION-TECH SOLUTIONS LIMITED (Ticker: GOLDTECH)...
# Error parsing GDELT data for AION-TECH SOLUTIONS LIMITED: Invalid JSON
# Starting processing for company: Goodluck India Limited (Ticker: GOODLUCK)
# Processing company: Goodluck India Limited (Ticker: GOODLUCK)...
# Error parsing GDELT data for Goodluck India Limited: Invalid JSON
# Starting processing for company: Graphite India Limited (Ticker: GRAPHITE)
# Processing company: Graphite India Limited (Ticker: GRAPHITE)...
# Error parsing GDELT data for Graphite India Limited: Invalid JSON
# Starting processing for company: Greaves Cotton Limited (Ticker: GREAVESCOT)
# Processing company: Greaves Cotton Limited (Ticker: GREAVESCOT)...
# Error parsing GDELT data for Greaves Cotton Limited: Invalid JSON
# Starting processing for company: Gujarat State Fertilizers & Chemicals Limited (Ticker: GSFC)
# Processing company: Gujarat State Fertilizers & Chemicals Limited (Ticker: GSFC)...
# Error parsing GDELT data for Gujarat State Fertilizers & Chemicals Limited: Invalid JSON
# Starting processing for company: GSS Infotech Limited (Ticker: GSS)
# Processing company: GSS Infotech Limited (Ticker: GSS)...
# Error parsing GDELT data for GSS Infotech Limited: Invalid JSON
# Starting processing for company: G-TEC JAINX EDUCATION LIMITED (Ticker: GTECJAINX)
# Processing company: G-TEC JAINX EDUCATION LIMITED (Ticker: GTECJAINX)...
# Error parsing GDELT data for G-TEC JAINX EDUCATION LIMITED: Invalid JSON
# Starting processing for company: GTL Limited (Ticker: GTL)
# Processing company: GTL Limited (Ticker: GTL)...
# Error parsing GDELT data for GTL Limited: Invalid JSON
# Starting processing for company: Gujarat Apollo Industries Limited (Ticker: GUJAPOLLO)
# Processing company: Gujarat Apollo Industries Limited (Ticker: GUJAPOLLO)...
# Error parsing GDELT data for Gujarat Apollo Industries Limited: Invalid JSON
# Starting processing for company: GP Petroleums Limited (Ticker: GULFPETRO)
# Processing company: GP Petroleums Limited (Ticker: GULFPETRO)...
# Error parsing GDELT data for GP Petroleums Limited: Invalid JSON
# Starting processing for company: GVP Infotech Limited (Ticker: GVPTECH)
# Processing company: GVP Infotech Limited (Ticker: GVPTECH)...
# Error parsing GDELT data for GVP Infotech Limited: Invalid JSON
# Starting processing for company: Sri Havisha Hospitality and Infrastructure Limited (Ticker: HAVISHA)
# Processing company: Sri Havisha Hospitality and Infrastructure Limited (Ticker: HAVISHA)...
# Error parsing GDELT data for Sri Havisha Hospitality and Infrastructure Limited: Invalid JSON
# Starting processing for company: HCL Infosystems Ltd (Ticker: HCL-INSYS)
# Processing company: HCL Infosystems Ltd (Ticker: HCL-INSYS)...
# Error parsing GDELT data for HCL Infosystems Ltd: Invalid JSON
# Starting processing for company: HCL Infosystems Limited (Ticker: HCL-INSYS)
# Processing company: HCL Infosystems Limited (Ticker: HCL-INSYS)...
# Error parsing GDELT data for HCL Infosystems Limited: Invalid JSON
# Starting processing for company: HDFC Life Insurance Company Limited (Ticker: HDFCLIFE)
# Processing company: HDFC Life Insurance Company Limited (Ticker: HDFCLIFE)...
# Error parsing GDELT data for HDFC Life Insurance Company Limited: Invalid JSON
# Starting processing for company: Heads UP Ventures Limited (Ticker: HEADSUP)
# Processing company: Heads UP Ventures Limited (Ticker: HEADSUP)...
# Error parsing GDELT data for Heads UP Ventures Limited: Invalid JSON
# Starting processing for company: HeidelbergCement India Limited (Ticker: HEIDELBERG)
# Processing company: HeidelbergCement India Limited (Ticker: HEIDELBERG)...
# Error parsing GDELT data for HeidelbergCement India Limited: Invalid JSON
# Starting processing for company: Heritage Foods Limited (Ticker: HERITGFOOD)
# Processing company: Heritage Foods Limited (Ticker: HERITGFOOD)...
# Error parsing GDELT data for Heritage Foods Limited: Invalid JSON
# Starting processing for company: Hero MotoCorp Limited (Ticker: HEROMOTOCO)
# Processing company: Hero MotoCorp Limited (Ticker: HEROMOTOCO)...
# Error parsing GDELT data for Hero MotoCorp Limited: Invalid JSON
# Starting processing for company: Heubach Colorants India Limited (Ticker: HEUBACHIND)
# Processing company: Heubach Colorants India Limited (Ticker: HEUBACHIND)...
# Error parsing GDELT data for Heubach Colorants India Limited: Invalid JSON
# Starting processing for company: HFCL Limited (Ticker: HFCL)
# Processing company: HFCL Limited (Ticker: HFCL)...
# Error parsing GDELT data for HFCL Limited: Invalid JSON
# Starting processing for company: Hinduja Global Solutions Limited (Ticker: HGS)
# Processing company: Hinduja Global Solutions Limited (Ticker: HGS)...
# Error parsing GDELT data for Hinduja Global Solutions Limited: Invalid JSON
# Starting processing for company: HIL Limited (Ticker: HIL)
# Processing company: HIL Limited (Ticker: HIL)...
# Error parsing GDELT data for HIL Limited: Invalid JSON
# Starting processing for company: Hindustan Unilever Limited (Ticker: HINDUNILVR)
# Processing company: Hindustan Unilever Limited (Ticker: HINDUNILVR)...
# Error parsing GDELT data for Hindustan Unilever Limited: Invalid JSON
# Starting processing for company: Hindware Home Innovation Limited (Ticker: HINDWAREAP)
# Processing company: Hindware Home Innovation Limited (Ticker: HINDWAREAP)...
# Error parsing GDELT data for Hindware Home Innovation Limited: Invalid JSON
# Starting processing for company: Hitech Corporation Limited (Ticker: HITECHCORP)
# Processing company: Hitech Corporation Limited (Ticker: HITECHCORP)...
# Error parsing GDELT data for Hitech Corporation Limited: Invalid JSON
# Starting processing for company: The Hi-Tech Gears Limited (Ticker: HITECHGEAR)
# Processing company: The Hi-Tech Gears Limited (Ticker: HITECHGEAR)...
# Error parsing GDELT data for The Hi-Tech Gears Limited: Invalid JSON
# Starting processing for company: HLV LIMITED (Ticker: HLVLTD)
# Processing company: HLV LIMITED (Ticker: HLVLTD)...
# Error parsing GDELT data for HLV LIMITED: Invalid JSON
# Starting processing for company: Honeywell Automation India Limited (Ticker: HONAUT)
# Processing company: Honeywell Automation India Limited (Ticker: HONAUT)...
# Error parsing GDELT data for Honeywell Automation India Limited: Invalid JSON
# Starting processing for company: Honda India Power Products Limited (Ticker: HONDAPOWER)
# Processing company: Honda India Power Products Limited (Ticker: HONDAPOWER)...
# Error parsing GDELT data for Honda India Power Products Limited: Invalid JSON
# Starting processing for company: Himadri Speciality Chemical Limited (Ticker: HSCL)
# Processing company: Himadri Speciality Chemical Limited (Ticker: HSCL)...
# Error parsing GDELT data for Himadri Speciality Chemical Limited: Invalid JSON
# Starting processing for company: Hubtown Limited (Ticker: HUBTOWN)
# Processing company: Hubtown Limited (Ticker: HUBTOWN)...
# Error parsing GDELT data for Hubtown Limited: Invalid JSON
# Starting processing for company: Huhtamaki India Limited (Ticker: HUHTAMAKI)
# Processing company: Huhtamaki India Limited (Ticker: HUHTAMAKI)...
# Error parsing GDELT data for Huhtamaki India Limited: Invalid JSON
# Starting processing for company: ICICI Bank Limited (Ticker: ICICIBANK)
# Processing company: ICICI Bank Limited (Ticker: ICICIBANK)...
# Error parsing GDELT data for ICICI Bank Limited: Invalid JSON
# Starting processing for company: IDBI Bank Limited (Ticker: IDBI)
# Processing company: IDBI Bank Limited (Ticker: IDBI)...
# Error parsing GDELT data for IDBI Bank Limited: Invalid JSON
# Starting processing for company: Vodafone Idea Limited (Ticker: IDEA)
# Processing company: Vodafone Idea Limited (Ticker: IDEA)...
# Error parsing GDELT data for Vodafone Idea Limited: Invalid JSON
# Starting processing for company: IDFC Limited (Ticker: IDFC)
# Processing company: IDFC Limited (Ticker: IDFC)...
# Error parsing GDELT data for IDFC Limited: Invalid JSON
# Starting processing for company: Idfc First Bank Limited (Ticker: IDFCFIRSTB)
# Processing company: Idfc First Bank Limited (Ticker: IDFCFIRSTB)...
# Error parsing GDELT data for Idfc First Bank Limited: Invalid JSON
# Starting processing for company: IFCI Limited (Ticker: IFCI)
# Processing company: IFCI Limited (Ticker: IFCI)...
# Error parsing GDELT data for IFCI Limited: Invalid JSON
# Starting processing for company: Igarashi Motors India Limited (Ticker: IGARASHI)
# Processing company: Igarashi Motors India Limited (Ticker: IGARASHI)...
# Error parsing GDELT data for Igarashi Motors India Limited: Invalid JSON
# Starting processing for company: IIFL Finance Limited (Ticker: IIFL)
# Processing company: IIFL Finance Limited (Ticker: IIFL)...
# Error parsing GDELT data for IIFL Finance Limited: Invalid JSON
# Starting processing for company: IL&FS Engineering and Construction Company Limited (Ticker: IL&FSENGG)
# Processing company: IL&FS Engineering and Construction Company Limited (Ticker: IL&FSENGG)...
# Error parsing GDELT data for IL&FS Engineering and Construction Company Limited: Invalid JSON
# Starting processing for company: Imagicaaworld Entertainment Limited (Ticker: IMAGICAA)
# Processing company: Imagicaaworld Entertainment Limited (Ticker: IMAGICAA)...
# Error parsing GDELT data for Imagicaaworld Entertainment Limited: Invalid JSON
# Starting processing for company: INCREDIBLE INDUSTRIES LIMITED (Ticker: INCREDIBLE)
# Processing company: INCREDIBLE INDUSTRIES LIMITED (Ticker: INCREDIBLE)...
# Error parsing GDELT data for INCREDIBLE INDUSTRIES LIMITED: Invalid JSON
# Starting processing for company: Indus Towers Limited (Ticker: INDUSTOWER)
# Processing company: Indus Towers Limited (Ticker: INDUSTOWER)...
# Error parsing GDELT data for Indus Towers Limited: Invalid JSON
# Starting processing for company: Infibeam Avenues Limited (Ticker: INFIBEAM)
# Processing company: Infibeam Avenues Limited (Ticker: INFIBEAM)...
# Error parsing GDELT data for Infibeam Avenues Limited: Invalid JSON
# Starting processing for company: INFOMEDIA PRESS LIMITED (Ticker: INFOMEDIA)
# Processing company: INFOMEDIA PRESS LIMITED (Ticker: INFOMEDIA)...
# Error parsing GDELT data for INFOMEDIA PRESS LIMITED: Invalid JSON
# Starting processing for company: Infosys Limited (Ticker: INFY)
# Processing company: Infosys Limited (Ticker: INFY)...
# Error parsing GDELT data for Infosys Limited: Invalid JSON
# Starting processing for company: Inspirisys Solutions Limited (Ticker: INSPIRISYS)
# Processing company: Inspirisys Solutions Limited (Ticker: INSPIRISYS)...
# Error parsing GDELT data for Inspirisys Solutions Limited: Invalid JSON
# Starting processing for company: ITD Cementation India Limited (Ticker: ITDCEM)
# Processing company: ITD Cementation India Limited (Ticker: ITDCEM)...
# Error parsing GDELT data for ITD Cementation India Limited: Invalid JSON
# Starting processing for company: IL&FS Investment Managers Limited (Ticker: IVC)
# Processing company: IL&FS Investment Managers Limited (Ticker: IVC)...
# Error parsing GDELT data for IL&FS Investment Managers Limited: Invalid JSON
# Starting processing for company: IZMO Limited (Ticker: IZMO)
# Processing company: IZMO Limited (Ticker: IZMO)...
# Error parsing GDELT data for IZMO Limited: Invalid JSON
# Starting processing for company: Jai Balaji Industries Limited (Ticker: JAIBALAJI)
# Processing company: Jai Balaji Industries Limited (Ticker: JAIBALAJI)...
# Error parsing GDELT data for Jai Balaji Industries Limited: Invalid JSON
# Starting processing for company: Jayaswal Neco Industries Limited (Ticker: JAYNECOIND)
# Processing company: Jayaswal Neco Industries Limited (Ticker: JAYNECOIND)...
# Error parsing GDELT data for Jayaswal Neco Industries Limited: Invalid JSON
# Starting processing for company: JBM Auto Limited (Ticker: JBMA)
# Processing company: JBM Auto Limited (Ticker: JBMA)...
# Error parsing GDELT data for JBM Auto Limited: Invalid JSON
# Starting processing for company: Johnson Controls  Hitachi Air Conditioning India Limited (Ticker: JCHAC)
# Processing company: Johnson Controls  Hitachi Air Conditioning India Limited (Ticker: JCHAC)...
# Error parsing GDELT data for Johnson Controls  Hitachi Air Conditioning India Limited: Invalid JSON
# Starting processing for company: Jindal Poly Films Limited (Ticker: JINDALPOLY)
# Processing company: Jindal Poly Films Limited (Ticker: JINDALPOLY)...
# Error parsing GDELT data for Jindal Poly Films Limited: Invalid JSON
# Starting processing for company: Jindal Saw Limited (Ticker: JINDALSAW)
# ...
# Error parsing GDELT data for Sunflag Iron And Steel Company Limited: Invalid JSON
# Starting processing for company: Sun Pharmaceutical Industries Limited (Ticker: SUNPHARMA)
# Processing company: Sun Pharmaceutical Industries Limited (Ticker: SUNPHARMA)...
# Error parsing GDELT data for Sun Pharmaceutical Industries Limited: Invalid JSON
# Starting processing for company: Sun TV Network Limited (Ticker: SUNTV)
# Processing company: Sun TV Network Limited (Ticker: SUNTV)...
# Error parsing GDELT data for Sun TV Network Limited: Invalid JSON
# Starting processing for company: SURANA SOLAR LIMITED (Ticker: SURANASOL)
# Processing company: SURANA SOLAR LIMITED (Ticker: SURANASOL)...
# Error parsing GDELT data for SURANA SOLAR LIMITED: Invalid JSON
# Starting processing for company: Surana Telecom and Power Limited (Ticker: SURANAT&P)
# Processing company: Surana Telecom and Power Limited (Ticker: SURANAT&P)...
# Error parsing GDELT data for Surana Telecom and Power Limited: Invalid JSON
# Starting processing for company: Suumaya Industries Limited (Ticker: SUULD)
# Processing company: Suumaya Industries Limited (Ticker: SUULD)...
# Error parsing GDELT data for Suumaya Industries Limited: Invalid JSON
# Starting processing for company: SVP GLOBAL TEXTILES LIMITED (Ticker: SVPGLOB)
# Processing company: SVP GLOBAL TEXTILES LIMITED (Ticker: SVPGLOB)...
# Error parsing GDELT data for SVP GLOBAL TEXTILES LIMITED: Invalid JSON
# Starting processing for company: Swelect Energy Systems Limited (Ticker: SWELECTES)
# Processing company: Swelect Energy Systems Limited (Ticker: SWELECTES)...
# Error parsing GDELT data for Swelect Energy Systems Limited: Invalid JSON
# Starting processing for company: Sterling and Wilson Renewable Energy Limited (Ticker: SWSOLAR)
# Processing company: Sterling and Wilson Renewable Energy Limited (Ticker: SWSOLAR)...
# Error parsing GDELT data for Sterling and Wilson Renewable Energy Limited: Invalid JSON
# Starting processing for company: Tanla Platforms Limited (Ticker: TANLA)
# Processing company: Tanla Platforms Limited (Ticker: TANLA)...
# Error parsing GDELT data for Tanla Platforms Limited: Invalid JSON
# Starting processing for company: Tara Chand InfraLogistic Solutions Limited (Ticker: TARACHAND)
# Processing company: Tara Chand InfraLogistic Solutions Limited (Ticker: TARACHAND)...
# Error parsing GDELT data for Tara Chand InfraLogistic Solutions Limited: Invalid JSON
# Starting processing for company: TARC Limited (Ticker: TARC)
# Processing company: TARC Limited (Ticker: TARC)...
# Error parsing GDELT data for TARC Limited: Invalid JSON
# Starting processing for company: Tarmat Limited (Ticker: TARMAT)
# Processing company: Tarmat Limited (Ticker: TARMAT)...
# Error parsing GDELT data for Tarmat Limited: Invalid JSON
# Starting processing for company: Tata Communications Limited (Ticker: TATACOMM)
# Processing company: Tata Communications Limited (Ticker: TATACOMM)...
# Error parsing GDELT data for Tata Communications Limited: Invalid JSON
# Starting processing for company: TATA CONSUMER PRODUCTS LIMITED (Ticker: TATACONSUM)
# Processing company: TATA CONSUMER PRODUCTS LIMITED (Ticker: TATACONSUM)...
# Error parsing GDELT data for TATA CONSUMER PRODUCTS LIMITED: Invalid JSON
# Starting processing for company: Tata Investment Corporation Limited (Ticker: TATAINVEST)
# Processing company: Tata Investment Corporation Limited (Ticker: TATAINVEST)...
# Error parsing GDELT data for Tata Investment Corporation Limited: Invalid JSON
# Starting processing for company: Tata Motors Limited (Ticker: TATAMOTORS)
# Processing company: Tata Motors Limited (Ticker: TATAMOTORS)...
# Error parsing GDELT data for Tata Motors Limited: Invalid JSON
# Starting processing for company: Tata Steel Limited (Ticker: TATASTEEL)
# Processing company: Tata Steel Limited (Ticker: TATASTEEL)...
# Error parsing GDELT data for Tata Steel Limited: Invalid JSON
# Starting processing for company: TECHINDIA NIRMAN LIMITED (Ticker: TECHIN)
# Processing company: TECHINDIA NIRMAN LIMITED (Ticker: TECHIN)...
# Error parsing GDELT data for TECHINDIA NIRMAN LIMITED: Invalid JSON
# Starting processing for company: Tembo Global Industries Limited (Ticker: TEMBO)
# Processing company: Tembo Global Industries Limited (Ticker: TEMBO)...
# Error parsing GDELT data for Tembo Global Industries Limited: Invalid JSON
# Starting processing for company: Texmaco Infrastructure & Holdings Limited (Ticker: TEXINFRA)
# Processing company: Texmaco Infrastructure & Holdings Limited (Ticker: TEXINFRA)...
# Error parsing GDELT data for Texmaco Infrastructure & Holdings Limited: Invalid JSON
# Starting processing for company: TGB BANQUETS AND HOTELS LIMITED (Ticker: TGBHOTELS)
# Processing company: TGB BANQUETS AND HOTELS LIMITED (Ticker: TGBHOTELS)...
# Error parsing GDELT data for TGB BANQUETS AND HOTELS LIMITED: Invalid JSON
# Starting processing for company: The Investment Trust Of India Limited (Ticker: THEINVEST)
# Processing company: The Investment Trust Of India Limited (Ticker: THEINVEST)...
# Error parsing GDELT data for The Investment Trust Of India Limited: Invalid JSON
# Starting processing for company: TIMKEN INDIA LTD (Ticker: TIMKEN)
# Processing company: TIMKEN INDIA LTD (Ticker: TIMKEN)...
# Error parsing GDELT data for TIMKEN INDIA LTD: Invalid JSON
# Starting processing for company: TITAGARH RAIL SYSTEMS LIMITED (Ticker: TITAGARH)
# Processing company: TITAGARH RAIL SYSTEMS LIMITED (Ticker: TITAGARH)...
# Error parsing GDELT data for TITAGARH RAIL SYSTEMS LIMITED: Invalid JSON
# Starting processing for company: Titan Company Limited (Ticker: TITAN)
# Processing company: Titan Company Limited (Ticker: TITAN)...
# Error parsing GDELT data for Titan Company Limited: Invalid JSON
# Starting processing for company: Teamo Productions HQ Limited (Ticker: TPHQ)
# Processing company: Teamo Productions HQ Limited (Ticker: TPHQ)...
# Error parsing GDELT data for Teamo Productions HQ Limited: Invalid JSON
# Starting processing for company: Trent Limited (Ticker: TRENT)
# Processing company: Trent Limited (Ticker: TRENT)...
# Error parsing GDELT data for Trent Limited: Invalid JSON
# Starting processing for company: Trident Limited (Ticker: TRIDENT)
# Processing company: Trident Limited (Ticker: TRIDENT)...
# Error parsing GDELT data for Trident Limited: Invalid JSON
# Starting processing for company: Trigyn Technologies Limited (Ticker: TRIGYN)
# Processing company: Trigyn Technologies Limited (Ticker: TRIGYN)...
# Error parsing GDELT data for Trigyn Technologies Limited: Invalid JSON
# Starting processing for company: TruCap Finance Limited (Ticker: TRU)
# Processing company: TruCap Finance Limited (Ticker: TRU)...
# Error parsing GDELT data for TruCap Finance Limited: Invalid JSON
# Starting processing for company: Tata Teleservices (Maharashtra) Limited (Ticker: TTML)
# Processing company: Tata Teleservices (Maharashtra) Limited (Ticker: TTML)...
# Error parsing GDELT data for Tata Teleservices (Maharashtra) Limited: Invalid JSON
# Starting processing for company: TV18 Broadcast Limited (Ticker: TV18BRDCST)
# Processing company: TV18 Broadcast Limited (Ticker: TV18BRDCST)...
# Error parsing GDELT data for TV18 Broadcast Limited: Invalid JSON
# Starting processing for company: TVS Holdings Limited (Ticker: TVSHLTD)
# Processing company: TVS Holdings Limited (Ticker: TVSHLTD)...
# Error parsing GDELT data for TVS Holdings Limited: Invalid JSON
# Starting processing for company: TVS Motor Company Limited (Ticker: TVSMOTOR)
# Processing company: TVS Motor Company Limited (Ticker: TVSMOTOR)...
# Error parsing GDELT data for TVS Motor Company Limited: Invalid JSON
# Starting processing for company: TVS Srichakra Ltd (Ticker: TVSSRICHAK)
# Processing company: TVS Srichakra Ltd (Ticker: TVSSRICHAK)...
# Error parsing GDELT data for TVS Srichakra Ltd: Invalid JSON
# Starting processing for company: UCAL LIMITED (Ticker: UCAL)
# Processing company: UCAL LIMITED (Ticker: UCAL)...
# Error parsing GDELT data for UCAL LIMITED: Invalid JSON
# Starting processing for company: UFLEX Limited (Ticker: UFLEX)
# Processing company: UFLEX Limited (Ticker: UFLEX)...
# Error parsing GDELT data for UFLEX Limited: Invalid JSON
# Starting processing for company: UltraTech Cement Limited (Ticker: ULTRACEMCO)
# Processing company: UltraTech Cement Limited (Ticker: ULTRACEMCO)...
# Error parsing GDELT data for UltraTech Cement Limited: Invalid JSON
# Starting processing for company: UNO Minda Limited (Ticker: UNOMINDA)
# Processing company: UNO Minda Limited (Ticker: UNOMINDA)...
# Error parsing GDELT data for UNO Minda Limited: Invalid JSON
# Starting processing for company: UPL Limited (Ticker: UPL)
# Processing company: UPL Limited (Ticker: UPL)...
# Error parsing GDELT data for UPL Limited: Invalid JSON
# Starting processing for company: Usha Martin Limited (Ticker: USHAMART)
# Processing company: Usha Martin Limited (Ticker: USHAMART)...
# Error parsing GDELT data for Usha Martin Limited: Invalid JSON
# Starting processing for company: V2 Retail Limited (Ticker: V2RETAIL)
# Processing company: V2 Retail Limited (Ticker: V2RETAIL)...
# Error parsing GDELT data for V2 Retail Limited: Invalid JSON
# Starting processing for company: Vaibhav Global Limited (Ticker: VAIBHAVGBL)
# Processing company: Vaibhav Global Limited (Ticker: VAIBHAVGBL)...
# Error parsing GDELT data for Vaibhav Global Limited: Invalid JSON
# Starting processing for company: VAKANGEE LIMITED (Ticker: VAKRANGEE)
# Processing company: VAKANGEE LIMITED (Ticker: VAKRANGEE)...
# Error parsing GDELT data for VAKANGEE LIMITED: Invalid JSON
# Starting processing for company: Vardhman Polytex Limited (Ticker: VARDMNPOLY)
# Processing company: Vardhman Polytex Limited (Ticker: VARDMNPOLY)...
# Error parsing GDELT data for Vardhman Polytex Limited: Invalid JSON
# Starting processing for company: Vedanta Limited (Ticker: VEDL)
# Processing company: Vedanta Limited (Ticker: VEDL)...
# Error parsing GDELT data for Vedanta Limited: Invalid JSON
# Starting processing for company: Venky's (India) Limited (Ticker: VENKEYS)
# Processing company: Venky's (India) Limited (Ticker: VENKEYS)...
# Error parsing GDELT data for Venky's (India) Limited: Invalid JSON
# Starting processing for company: Vertoz Limited (Ticker: VERTOZ)
# Processing company: Vertoz Limited (Ticker: VERTOZ)...
# Error parsing GDELT data for Vertoz Limited: Invalid JSON
# Starting processing for company: Vardhman Holdings Limited (Ticker: VHL)
# Processing company: Vardhman Holdings Limited (Ticker: VHL)...
# Error parsing GDELT data for Vardhman Holdings Limited: Invalid JSON
# Starting processing for company: Vidhi Specialty Food Ingredients Limited (Ticker: VIDHIING)
# Processing company: Vidhi Specialty Food Ingredients Limited (Ticker: VIDHIING)...
# Error parsing GDELT data for Vidhi Specialty Food Ingredients Limited: Invalid JSON
# Starting processing for company: Vikas EcoTech Limited (Ticker: VIKASECO)
# Processing company: Vikas EcoTech Limited (Ticker: VIKASECO)...
# Error parsing GDELT data for Vikas EcoTech Limited: Invalid JSON
# Starting processing for company: Vikas Lifecare Limited (Ticker: VIKASLIFE)
# Processing company: Vikas Lifecare Limited (Ticker: VIKASLIFE)...
# Error parsing GDELT data for Vikas Lifecare Limited: Invalid JSON
# Starting processing for company: VIP CLOTHING LIMITED (Ticker: VIPCLOTHNG)
# Processing company: VIP CLOTHING LIMITED (Ticker: VIPCLOTHNG)...
# Error parsing GDELT data for VIP CLOTHING LIMITED: Invalid JSON
# Starting processing for company: Vardhman Textiles Limited (Ticker: VTL)
# Processing company: Vardhman Textiles Limited (Ticker: VTL)...
# Error parsing GDELT data for Vardhman Textiles Limited: Invalid JSON
# Starting processing for company: Websol Energy System Limited (Ticker: WEBELSOLAR)
# Processing company: Websol Energy System Limited (Ticker: WEBELSOLAR)...
# Error parsing GDELT data for Websol Energy System Limited: Invalid JSON
# Starting processing for company: Weizmann Limited (Ticker: WEIZMANIND)
# Processing company: Weizmann Limited (Ticker: WEIZMANIND)...
# Error parsing GDELT data for Weizmann Limited: Invalid JSON
# Starting processing for company: Wonder Electricals Limited (Ticker: WEL)
# Processing company: Wonder Electricals Limited (Ticker: WEL)...
# Error parsing GDELT data for Wonder Electricals Limited: Invalid JSON
# Starting processing for company: Welspun Corp Limited (Ticker: WELCORP)
# Processing company: Welspun Corp Limited (Ticker: WELCORP)...
# Error parsing GDELT data for Welspun Corp Limited: Invalid JSON
# Starting processing for company: Welspun Enterprises Limited (Ticker: WELENT)
# Processing company: Welspun Enterprises Limited (Ticker: WELENT)...
# Error parsing GDELT data for Welspun Enterprises Limited: Invalid JSON
# Starting processing for company: Welspun Living Limited (Ticker: WELSPUNLIV)
# Processing company: Welspun Living Limited (Ticker: WELSPUNLIV)...
# Error parsing GDELT data for Welspun Living Limited: Invalid JSON
# Starting processing for company: WESTLIFE FOODWORLD LIMITED (Ticker: WESTLIFE)
# Processing company: WESTLIFE FOODWORLD LIMITED (Ticker: WESTLIFE)...
# Error parsing GDELT data for WESTLIFE FOODWORLD LIMITED: Invalid JSON
# Starting processing for company: WE WIN LIMITED (Ticker: WEWIN)
# Processing company: WE WIN LIMITED (Ticker: WEWIN)...
# Error parsing GDELT data for WE WIN LIMITED: Invalid JSON
# Starting processing for company: West Coast Paper Mills Limited (Ticker: WSTCSTPAPR)
# Processing company: West Coast Paper Mills Limited (Ticker: WSTCSTPAPR)...
# Error parsing GDELT data for West Coast Paper Mills Limited: Invalid JSON
# Starting processing for company: Xchanging Solutions Limited (Ticker: XCHANGING)
# Processing company: Xchanging Solutions Limited (Ticker: XCHANGING)...
# Error parsing GDELT data for Xchanging Solutions Limited: Invalid JSON
# Starting processing for company: Yaarii Digital Integrated Services Limited (Ticker: YAARI)
# Processing company: Yaarii Digital Integrated Services Limited (Ticker: YAARI)...
# Error parsing GDELT data for Yaarii Digital Integrated Services Limited: Invalid JSON
# Starting processing for company: Yaari Digital Integrated Services Limited (Ticker: YAARI)
# Processing company: Yaari Digital Integrated Services Limited (Ticker: YAARI)...
# Error parsing GDELT data for Yaari Digital Integrated Services Limited: Invalid JSON
# Starting processing for company: Zee Entertainment Enterprises Limited (Ticker: ZEEL)
# Processing company: Zee Entertainment Enterprises Limited (Ticker: ZEEL)...
# Error parsing GDELT data for Zee Entertainment Enterprises Limited: Invalid JSON
# Starting processing for company: Zee Media Corporation Limited (Ticker: ZEEMEDIA)
# Processing company: Zee Media Corporation Limited (Ticker: ZEEMEDIA)...
# Error parsing GDELT data for Zee Media Corporation Limited: Invalid JSON
# Starting processing for company: Zenith Steel Pipes & Industries Limited (Ticker: ZENITHSTL)
# Processing company: Zenith Steel Pipes & Industries Limited (Ticker: ZENITHSTL)...
# Error parsing GDELT data for Zenith Steel Pipes & Industries Limited: Invalid JSON
# Starting processing for company: Zensar Technologies Limited (Ticker: ZENSARTECH)
# Processing company: Zensar Technologies Limited (Ticker: ZENSARTECH)...
# Error parsing GDELT data for Zensar Technologies Limited: Invalid JSON
# Starting processing for company: ZF Commercial Vehicle Control Systems India Limited (Ticker: ZFCVINDIA)
# Processing company: ZF Commercial Vehicle Control Systems India Limited (Ticker: ZFCVINDIA)...
# Error parsing GDELT data for ZF Commercial Vehicle Control Systems India Limited: Invalid JSON
# Starting processing for company: ZUARI INDUSTRIES LIMITED (Ticker: ZUARIIND)
# Processing company: ZUARI INDUSTRIES LIMITED (Ticker: ZUARIIND)...
# Error parsing GDELT data for ZUARI INDUSTRIES LIMITED: Invalid JSON
# Starting processing for company: ZUARI GLOBAL LIMITED (Ticker: ZUARIIND)
# Processing company: ZUARI GLOBAL LIMITED (Ticker: ZUARIIND)...
# Error parsing GDELT data for ZUARI GLOBAL LIMITED: Invalid JSON
# Starting processing for company: Zydus Lifesciences Limited (Ticker: ZYDUSLIFE)
# Processing company: Zydus Lifesciences Limited (Ticker: ZYDUSLIFE)...
# Error parsing GDELT data for Zydus Lifesciences Limited: Invalid JSON
# Final data saved to 'company_sentiment_dataset.csv'

# %%
# Load the sentiment dataset
sentiment_df = pd.read_csv('company_sentiment_dataset.csv')  # Assuming this is the filename

# Load the ticker-to-company mapping file
namechange_df = pd.read_csv('namechange.csv', encoding='ISO-8859-1')

# Merge the sentiment dataset with the ticker file to get the SYMBOL for each company
sentiment_df = sentiment_df.merge(namechange_df[['SYMBOL', 'COMPANY']], left_on='company', right_on='COMPANY', how='left')

# Drop the 'COMPANY' column as it's no longer needed after mapping to SYMBOL
sentiment_df = sentiment_df.drop(columns=['company'])

# %%
len(sentiment_df)
# Out:
# 69475

# %%
# Load the main stock dataset (with all stock features)
stock_df = pd.read_parquet('intermediate_self_sufficient_2.parquet')  # Replace with the correct file path

# Ensure the 'Date' column in the stock data is in datetime format for accurate merging
stock_df['Date'] = pd.to_datetime(stock_df['Date'])

# Ensure the 'date' column in the sentiment data is also in datetime format
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

# Merge the stock dataset with the sentiment dataset on 'Date' and 'SYMBOL'
merged_df = stock_df.merge(sentiment_df, left_on=['Date', 'Company_ID'], right_on=['date', 'SYMBOL'], how='left')

# Drop unnecessary columns like 'date' and 'SYMBOL' after merging
merged_df = merged_df.drop(columns=['date', 'SYMBOL'])

# Fill missing sentiment scores with 0 (neutral sentiment)
merged_df['sentiment_score'].fillna(0, inplace=True)

# Save the merged dataset to inspect and verify
merged_df.to_parquet('merged_with_sentiment_interim1.parquet')
print("Merged dataset saved as 'merged_with_sentiment_interim1.parquet'.")
# Out:
# Merged dataset saved as 'merged_with_sentiment_interim1.parquet'.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from tqdm import tqdm  # Progress bar
import numpy as np

# Load the merged dataset
print("Loading the merged dataset...")
merged_df = pd.read_parquet('merged_with_sentiment_interim1.parquet')
print("Merged dataset loaded.")

# Create lagged sentiment features (1-day, 5-day, 10-day lags)
print("Creating lagged sentiment features...")
lags = [1, 5, 10]
for lag in lags:
    print(f"Processing {lag}-day lag sentiment...")
    # Create lagged sentiment with a group-by and shift
    merged_df[f'Lagged_Sentiment_{lag}'] = merged_df.groupby('Company_ID')['sentiment_score'].transform(lambda x: x.shift(lag))
print("Lagged sentiment features created.")

# Define the features related to market sentiment (including lagged sentiment)
sentiment_features = [
    'Price_Change', 'Price_Change_Percent', 'Volume_Change', 'Volume_Change_Percent',
    'Rolling_Std_Close', 'Rolling_Mean_Close', 'Rolling_Max_Close', 'Rolling_Min_Close',
    'Z_Score_Close', 'Momentum', 'OBV_Change', 'Volume_Ratio',
    'Lagged_Sentiment_1', 'Lagged_Sentiment_5', 'Lagged_Sentiment_10'
]

# Drop rows with missing values in sentiment-related features
print("Dropping rows with missing sentiment-related features...")
merged_df = merged_df.dropna(subset=sentiment_features)
print(f"{len(merged_df)} rows remaining after dropping missing values.")

# Ensure all features are finite (remove rows with inf or very large values)
print("Ensuring all feature values are finite...")
X = merged_df[sentiment_features]
X = X.replace([np.inf, -np.inf], np.nan)  # Replace infinities with NaN
X = X.dropna()  # Drop rows with any NaN values
y = merged_df.loc[X.index, 'sentiment_score']  # Make sure to align y with X after dropping NaNs

print("Feature matrix cleaned. Proceeding to model fitting...")

# Fit a linear regression model to find optimal weights
print("Fitting the linear regression model...")
model = LinearRegression()
model.fit(X, y)
print("Model fitting completed.")

# Get the feature weights (coefficients)
weights = model.coef_

# Print the feature weights
print("Feature Weights:")
for feature, weight in zip(sentiment_features, weights):
    print(f"{feature}: {weight}")

# Save feature weights to a CSV for reference
print("Saving feature weights to 'feature_weights_final.csv'...")
weights_df = pd.DataFrame({'Feature': sentiment_features, 'Weight': weights})
weights_df.to_csv('feature_weights_final.csv', index=False)
print("Feature weights saved.")

# Calculate the new sentiment metric (weighted sum of features)
print("Calculating the new weighted sentiment metric...")
weighted_sentiment = (X * weights).sum(axis=1)
merged_df.loc[X.index, 'Weighted_Sentiment_Metric'] = weighted_sentiment
print("Weighted sentiment metric calculated.")

# Save the merged dataset with the new weighted sentiment metric for future use
print("Saving the final merged dataset with the new weighted sentiment metric...")
merged_df.to_parquet('merged_with_weighted_sentiment_final.parquet')
print("Final merged dataset saved as 'merged_with_weighted_sentiment_final.parquet'.")
# Out:
# Loading the merged dataset...
# Merged dataset loaded.
# Creating lagged sentiment features...
# Processing 1-day lag sentiment...
# Processing 5-day lag sentiment...
# Processing 10-day lag sentiment...
# Lagged sentiment features created.
# Dropping rows with missing sentiment-related features...
# 6409090 rows remaining after dropping missing values.
# Ensuring all feature values are finite...
# Feature matrix cleaned. Proceeding to model fitting...
# Fitting the linear regression model...
# Model fitting completed.
# Feature Weights:
# Price_Change: -4.11574402906927e-09
# Price_Change_Percent: 2.5666542822369083e-07
# Volume_Change: -1.7827567442081687e-12
# Volume_Change_Percent: 1.327662738994281e-11
# Rolling_Std_Close: -1.4815757236669486e-08
# Rolling_Mean_Close: 2.7945749905191854e-08
# Rolling_Max_Close: -2.3446638641760268e-08
# Rolling_Min_Close: 6.3043831318904855e-09
# Z_Score_Close: 2.3494891078401505e-05
# Momentum: 3.099515856255062e-09
# OBV_Change: 4.1784918060281585e-13
# Volume_Ratio: -2.5643216849827193e-05
# Lagged_Sentiment_1: 0.47780144175730216
# Lagged_Sentiment_5: 0.27050159360081344
# Lagged_Sentiment_10: 0.24874242898744134
# Saving feature weights to 'feature_weights_final.csv'...
# Feature weights saved.
# Calculating the new weighted sentiment metric...
# Weighted sentiment metric calculated.
# Saving the final merged dataset with the new weighted sentiment metric...
# Final merged dataset saved as 'merged_with_weighted_sentiment_final.parquet'.

# %%
import pandas as pd
check = pd.read_parquet('merged_with_weighted_sentiment_final.parquet')
check.columns
# Out:
# Index(['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Adj Close_x',
#        'Volume_x', 'Company_ID', 'VWAP_x', 'MACD_x', 'MACD_Signal_x',
#        'MACD_Hist_x', 'SMA_20', 'EMA_20', 'WMA_20', 'Upper_Band',
#        'Middle_Band', 'Lower_Band', 'ATR_14', 'RSI_14', 'Stoch_K', 'Stoch_D',
#        'OBV', 'SAR', 'CCI_20', 'ROC', 'Price_Change', 'Price_Change_Percent',
#        'Volume_Change', 'Volume_Change_Percent', 'High_Low_Spread',
#        'Close_Open_Ratio', 'High_Low_Ratio', 'Price_Range',
#        'Price_Volume_Product', 'Lag_Close_x_1', 'Lag_Volume_x_1',
#        'Lag_Close_x_5', 'Lag_Volume_x_5', 'Lag_Close_x_10', 'Lag_Volume_x_10',
#        'Day_of_Week', 'Month', 'Quarter', 'Week_of_Year', 'Rolling_Std_Close',
#        'Rolling_Std_Volume', 'Rolling_Mean_Close', 'Rolling_Max_Close',
#        'Rolling_Min_Close', 'Rolling_Price_Range', 'Z_Score_Close', 'Momentum',
#        'Price_Acceleration', 'OBV_Change', 'Volume_Ratio', 'Rolling_Return',
#        'Kurtosis', 'Skewness', 'Sharpe_Ratio', 'Fib_Level_0.236',
#        'Fib_Level_0.382', 'Fib_Level_0.618', 'Pivot_Point', 'ROC_5', 'ROC_10',
#        'sentiment_score', 'COMPANY', 'Lagged_Sentiment_1',
#        'Lagged_Sentiment_5', 'Lagged_Sentiment_10',
#        'Weighted_Sentiment_Metric'],
#       dtype='object')
